# %%
from konlpy.tag import Komoran

# %%
komoran = Komoran(userdic='./user_dic.tsv')
text = "우리 챗봇은 엔엘피를 좋아해. 그리고 나는 내일, 어제의 너와 만난다를 읽었어"
pos = komoran.pos(text)
print(pos)
# Out:
# [('우리', 'NP'), ('챗봇은', 'NA'), ('엔엘피', 'NNG'), ('를', 'JKO'), ('좋아하', 'VV'), ('아', 'EF'), ('.', 'SF'), ('그리고', 'MAJ'), ('나는 내일, 어제의 너와 만난다', 'NNG'), ('를', 'JKO'), ('읽', 'VV'), ('었', 'EP'), ('어', 'EC')]

# %%
text = "어서 옵서예"
pos = komoran.pos(text)
print(pos)
# Out:
# [('어서', 'MAG'), ('옵', 'EP'), ('서예', 'NNG')]
